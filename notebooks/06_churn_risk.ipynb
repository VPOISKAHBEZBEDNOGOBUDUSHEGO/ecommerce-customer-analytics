# %% [markdown]
# # 6. Классификация риска неактивности
#
# Цель задаётся правилом `Recency > 180 дней`, а модель использует Frequency и Monetary. Это классификация клиентов на текущем срезе. Она не является прогнозом оттока во времени: для такого вывода нужны временное разделение данных и будущая целевая переменная.

# %%
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ARTIFACTS = ROOT / 'artifacts'
ARTIFACTS.mkdir(exist_ok=True)

# %%
import pandas as pd
from ecommerce_analysis.churn import train_churn_risk_classifier

rfm = pd.read_csv(ARTIFACTS / 'rfm_customers.csv', index_col=0)
result = train_churn_risk_classifier(rfm, threshold_days=180)
pd.DataFrame(result.report).T

# %% [markdown]
# Основная метрика для рискового класса - recall, но её нужно рассматривать вместе с precision: высокая полнота ценой большого числа ложных срабатываний может сделать кампанию удержания дорогой.
