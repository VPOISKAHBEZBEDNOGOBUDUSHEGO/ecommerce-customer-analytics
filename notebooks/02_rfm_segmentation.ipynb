# %% [markdown]
# # 2. RFM-сегментация
#
# На уровне клиента рассчитываются давность последней покупки, число уникальных заказов и выручка. Баллы назначаются по квинтилям. Правила сегментов взаимоисключающие: `Can't Lose` соответствует R=1, а `At Risk` - R=2, поэтому обе ветки достижимы.

# %%
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ARTIFACTS = ROOT / 'artifacts'
ARTIFACTS.mkdir(exist_ok=True)

# %%
import pandas as pd
from ecommerce_analysis.rfm import build_rfm, segment_summary

clean = pd.read_pickle(ARTIFACTS / 'transactions_clean.pkl')
rfm = build_rfm(clean)
summary = segment_summary(rfm)
summary

# %%
rfm.to_csv(ARTIFACTS / 'rfm_customers.csv')
summary.to_csv(ARTIFACTS / 'segment_summary.csv')
rfm['Segment'].value_counts()
