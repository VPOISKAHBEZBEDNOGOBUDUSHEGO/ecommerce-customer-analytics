# %% [markdown]
# # 1. Очистка транзакций
#
# Цель этапа - получить воспроизводимый набор валидных продаж. Удаляются точные дубликаты, строки без клиента или описания, отменённые счета, некорректные даты, неположительные количество и цена. Отчёт показывает вклад каждого правила и делает очистку проверяемой.

# %%
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ARTIFACTS = ROOT / 'artifacts'
ARTIFACTS.mkdir(exist_ok=True)

# %%
import pandas as pd
from ecommerce_analysis.cleaning import clean_transactions

raw = pd.read_excel(ROOT / 'Online Retail.xlsx')
clean, report = clean_transactions(raw)
report.to_dict()

# %%
clean.head()

# %%
clean.to_pickle(ARTIFACTS / 'transactions_clean.pkl')
print(f'Сохранено строк: {len(clean):,}')
