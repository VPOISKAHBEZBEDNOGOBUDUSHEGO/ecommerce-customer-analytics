# %% [markdown]
# # 3. ABC/XYZ-анализ ассортимента
#
# ABC отражает вклад товара в накопленную выручку. XYZ оценивает стабильность помесячного спроса. В отличие от исходного расчёта месяцы без продаж заполняются нулями, поэтому коэффициент вариации не занижается.

# %%
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ARTIFACTS = ROOT / 'artifacts'
ARTIFACTS.mkdir(exist_ok=True)

# %%
import pandas as pd
from ecommerce_analysis.assortment import build_abc_xyz

clean = pd.read_pickle(ARTIFACTS / 'transactions_clean.pkl')
abc_xyz = build_abc_xyz(clean)
abc_xyz['Grade'].value_counts().sort_index()

# %%
abc_xyz.to_csv(ARTIFACTS / 'abc_xyz.csv')
abc_xyz.head(10)
