# %% [markdown]
# # 4. Кластеризация клиентов
#
# K-means применяется к стандартизированным RFM-признакам. Номера кластеров не получают заранее заданных бизнес-названий: смысл каждого кластера определяется по фактическому профилю после обучения.

# %%
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ARTIFACTS = ROOT / 'artifacts'
ARTIFACTS.mkdir(exist_ok=True)

# %%
import pandas as pd
from ecommerce_analysis.clustering import cluster_customers

rfm = pd.read_csv(ARTIFACTS / 'rfm_customers.csv', index_col=0)
clustered, profile = cluster_customers(rfm, n_clusters=4)
profile

# %%
pd.crosstab(clustered['Segment'], clustered['Cluster'])
